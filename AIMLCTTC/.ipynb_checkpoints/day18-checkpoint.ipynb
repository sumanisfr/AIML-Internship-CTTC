# %% [markdown]
# # Day :- 18

# %%
# importing the librareis
import cv2
import matplotlib.pyplot as plt

# %%
#face Detection (manually)
major = cv2.imread(r"C:\Users\suman\OneDrive\Documents\Desktop\AIML-CTTC-ALL-NOTES\major.jpeg")
plt.imshow(major[::,::,::-1])
plt.grid()
plt.show()

# %%
plt.grid()

# %%
cv2.rectangle(major,(100,100),(330,330),(255,0,0),4)
plt.imshow(major[::,::,::-1])
plt.show()

# %%
# Face Detection using HarCasCade algorithim.
face = r"C:\Users\suman\OneDrive\Documents\Desktop\AIML-CTTC-ALL-NOTES\haarcascade_frontalface_default.xml"
model = cv2.CascadeClassifier(face)


img = cv2.imread(r"C:\Users\suman\OneDrive\Documents\Desktop\AIML-CTTC-ALL-NOTES\major.jpeg")
facepoint = model.detectMultiScale(img)
for x,y,w,h in facepoint:
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),4)
plt.imshow(img[::,::,::-1])
plt.show()

# %%
# Face Detection using HarCasCade algorithim.
face = r"C:\Users\suman\OneDrive\Documents\Desktop\AIML-CTTC-ALL-NOTES\haarcascade_frontalface_default.xml"
model = cv2.CascadeClassifier(face)


img2 = cv2.imread(r"C:\Users\suman\OneDrive\Documents\Desktop\AIML-CTTC-ALL-NOTES\All_Notes_By_Mam\new_image.jpg")
facepoint = model.detectMultiScale(img2)
for x,y,w,h in facepoint:
    cv2.rectangle(img2,(x,y),(x+w,y+h),(255,0,0),4)
plt.imshow(img2[::,::,::-1])
plt.show()

# %%
# Face Detection using HarCasCade algorithim.
face = r"C:\Users\suman\OneDrive\Documents\Desktop\AIML-CTTC-ALL-NOTES\haarcascade_frontalface_default.xml"
model = cv2.CascadeClassifier(face)


img3 = cv2.imread(r"C:\Users\suman\OneDrive\Documents\Desktop\AIML-CTTC-ALL-NOTES\cse_16.jpg")
facepoint = model.detectMultiScale(img3)
for x,y,w,h in facepoint:
    cv2.rectangle(img3,(x,y),(x+w,y+h),(0,0,255),8)
plt.imshow(img3[::,::,::-1])
plt.show()

# %% [markdown]
# # Deep Learning:-
# ###### DL is inspired from the structure and function of Neural networks of Human brain.
# ##### DL is able to work on large or huge amount of data where it can solve complex problems extracts features and pattern automatically.
# ##### In Machine learning training is fast and testing is slow.
# ##### In Deep learning training is slow and testing is fast.
# ##### Uses of DL :- Medical sector,Self-driven car,Robotics.

# %%
note = cv2.imread(r"C:\Users\suman\OneDrive\Documents\Desktop\AIML-CTTC-ALL-NOTES\Deep_Learning.jpg")
plt.imshow(note)
plt.show()

# %%
# Single Layer precetron model consist of single Layered Neural network or Single Layer output.

# %% [markdown]
# ## ANN :- Artificial Neural network :-
# ###### ANN is a type of inspired by how human brain works
# ###### just like human brains have neurons to process , send message ANN also have artificial neurons (also called node ) to learn patterns make decision & Recognize things
# #####  ANN consist 3 layer:-
# ######     1.input layer :- It take the input inthe from of image,sound,number.
# ######     2. hidden Layer :- It process the data ,learn the patterns.
# ######     3. Output layer :- it gives the final results.

# %% [markdown]
# ### What are Difference between ML vs DL
# ##### 1. Data Dependency
# ##### 2. Hardware Dependency
# ##### 3. Feature Engineering
# ##### 4. Problem Solving Approach
# ##### 5. Exucution Time
# ##### 6. Interpretibilty

# %% [markdown]
# ## 28/06/2025

# %% [markdown]
# #### Activation function:-Decides
#
# ##### Types of Activation function :-
# * Linear A.f  :- (y=mx+c) range:- -00 to +00  (Continuous)
# * Sigmoid A.f :- [y = 1/1+epow-x]  range:-0 to 1  (categoriecal)
# * TanH A.f :- (Hyperbolic Tangent) :-[y = 1-e pow-2x/1-e pow+2x] range: -1 to 1.   (categoriecal)
# * ReLu:-(Rectified Linear unit) :- range:-(0 to 00)   (Continuous & categoriecal)

# %% [markdown]
# ##### Loss function :- Loss Function helps to calculate the predicated values and the actual value.
# ###### Common Loss Functions in Deep Learning:-
# * Mean Squared Error (MSE):
# * Mean Absolute Error (MAE):
# * Binary Cross-Entropy (Log Loss):
# * Binary Cross-Entropy (Log Loss):
# * categorical Cross-Entropy (Log Loss):
