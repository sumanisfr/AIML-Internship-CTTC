# %% [markdown]
# <h4>MACHINE LEARNING:-Machine Learns without being explicitly programmed.</h4>

# %%
#SEMI SUPERVISED ML:- IT IS A HYBRID MODEL BECAUSE IT A COMBINATION OF SUPERVISED AND UNSUPERVISED ML.
#HERE WE PROVIDE THE MACHINE SOME LABELLED DATAS AND SOME UNLABBEL DATAS

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
avt = pd.read_csv(r"C:\Users\suman\OneDrive\Documents\Desktop\AIML-CTTC-ALL-NOTES\Advertising-for ml(Linear Regressin)\advertising.csv")
avt
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
avt.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
des = avt.describe(include = 'all')
des
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
avt.dtypes
# Out:
# TV           float64
# Radio        float64
# Newspaper    float64
# Sales        float64
# dtype: object

# %%
for i in avt.columns:
    print(i,":",avt[i].unique())
# Out:
# TV : [230.1  44.5  17.2 151.5 180.8   8.7  57.5 120.2   8.6 199.8  66.1 214.7
#   23.8  97.5 204.1 195.4  67.8 281.4  69.2 147.3 218.4 237.4  13.2 228.3
#   62.3 262.9 142.9 240.1 248.8  70.6 292.9 112.9  97.2 265.6  95.7 290.7
#  266.9  74.7  43.1 228.  202.5 177.  293.6 206.9  25.1 175.1  89.7 239.9
#  227.2  66.9 100.4 216.4 182.6 262.7 198.9   7.3 136.2 210.8 210.7  53.5
#  261.3 239.3 102.7 131.1  69.   31.5 139.3 216.8 199.1 109.8  26.8 129.4
#  213.4  16.9  27.5 120.5   5.4 116.   76.4 239.8  75.3  68.4 213.5 193.2
#   76.3 110.7  88.3 134.3  28.6 217.7 250.9 107.4 163.3 197.6 184.9 289.7
#  135.2 222.4 296.4 280.2 187.9 238.2 137.9  25.   90.4  13.1 255.4 225.8
#  241.7 175.7 209.6  78.2  75.1 139.2 125.7  19.4 141.3  18.8 224.  123.1
#  229.5  87.2   7.8  80.2 220.3  59.6   0.7 265.2   8.4 219.8  36.9  48.3
#   25.6 273.7  43.   73.4 193.7 220.5 104.6  96.2 140.3 243.2  38.   44.7
#  280.7 121.  171.3 187.8   4.1  93.9 149.8  11.7 131.7 172.5  85.7 188.4
# ...

# %%
avt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %% [markdown]
# <H1>DATA VISUALISATION</H1>

# %%
sns.scatterplot(x = avt.TV,y =avt.Sales,palette = "hot",hue = avt.Sales)
plt.show()

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
sns.scatterplot(x = avt.Radio,y =avt.Sales,palette = "hot",hue = avt.Sales)
plt.show()

# %%
sns.scatterplot(x = avt.Newspaper,y =avt.Sales,palette = "hot",hue = avt.Sales)
plt.show()

# %%
sns.lineplot(x = avt.Newspaper,y =avt.Sales,palette = "hot",hue = avt.Sales)
plt.show()

# %%
sns.lineplot(x = avt.Radio,y =avt.Sales,palette = "hot",hue = avt.Sales)
plt.show()

# %%
sns.lineplot(x = avt.Newspaper,y =avt.Sales,palette = "hot",hue = avt.Sales)
plt.show()

# %%
sns.jointplot(x = avt.Newspaper,y =avt.Sales,palette = "hot",hue = avt.Sales)
plt.show()

# %%
c = avt.corr()
c
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.901208
# Radio      0.054809  1.000000   0.354104  0.349631
# Newspaper  0.056648  0.354104   1.000000  0.157960
# Sales      0.901208  0.349631   0.157960  1.000000

# %%
sns.heatmap(c,annot = True,cmap = "Greens")
plt.show()

# %% [markdown]
# <h1>ENCONDING :- CONVERTING STRING TO INTEGER WE DONT NEED HERE AS NO S</h1>

# %%
#ENCODING

# %%
#CREATION OF IP/OP:-
# we take a variable ip that will store all input values except the target one for here tv radio and newspaper
ip = avt.drop('Sales',axis = 1)
ip.head()
# Out:
#       TV  Radio  Newspaper
# 0  230.1   37.8       69.2
# 1   44.5   39.3       45.1
# 2   17.2   45.9       69.3
# 3  151.5   41.3       58.5
# 4  180.8   10.8       58.4

# %%
op = avt.Sales
op.head()
# Out:
# 0    22.1
# 1    10.4
# 2    12.0
# 3    16.5
# 4    17.9
# Name: Sales, dtype: float64

# %% [markdown]
# <H1> DAY 14 STARTS</H1>

# %%
#Train Test Split:-
#splitting 100% of the data to training data to training and testing data.
# We need to give 80 percent data to machine
from sklearn.model_selection import train_test_split

# %%
#Input Training data = xtrain
#Output Training data  = ytrain
#Input Testing data  = xtest
#Output Testing data  = ytest
#train_size = 0.8
#or
#test_size = 0.2
xtrain,xtest,ytrain,ytest = train_test_split(ip,op,test_size = 0.8,random_state = 5) 
#it executes untill  5 times 5th one will be final
# xtrain, xtest, ytrain, ytest = train_test_split(ip, op, test_size=0.2, random_state=5)

# %%
# INCORRECT (causes SyntaxError):
# xtrain,xtest,ytrain,ytest = train_test_split(ip,op,test_size = 0.8,'''random_state = 5''')

# CORRECT version:
xtrain, xtest, ytrain, ytest = train_test_split(ip, op, test_size=0.2, random_state=5)

# Alternative correct versions:
# Using train_size instead
# xtrain, xtest, ytrain, ytest = train_test_split(ip, op, train_size=0.8, random_state=5)

# With proper spacing
# xtrain, xtest, ytrain, ytest = train_test_split(ip, op, test_size=0.2, random_state=5)

# Complete working example:
from sklearn.model_selection import train_test_split
import numpy as np

# Sample data (replace with your actual data)
ip = np.random.rand(100, 4)  # 100 samples, 4 features
op = np.random.randint(0, 2, 100)  # 100 binary target values

# Correct train-test split
xtrain, xtest, ytrain, ytest = train_test_split(ip, op, test_size=0.2, random_state=5)

print(f"Training data shape: {xtrain.shape}")
print(f"Testing data shape: {xtest.shape}")
print(f"Training labels shape: {ytrain.shape}")
print(f"Testing labels shape: {ytest.shape}")
# Out:
# Training data shape: (80, 4)
# Testing data shape: (20, 4)
# Training labels shape: (80,)
# Testing labels shape: (20,)

# %%
# print(xtrain.head())
# print(xtrain.head())  # This won't work with NumPy arrays
# Option 1: Array slicing (recommended)
print(xtrain[:5])  # Shows first 5 rows

# Option 2: Convert to DataFrame first
print(pd.DataFrame(xtrain).head())

# Option 3: Check shape and first few elements
print(f"Shape: {xtrain.shape}")
print(f"First 5 rows:\n{xtrain[:5]}")
# Out:
# [[0.03519988 0.26836016 0.4858765  0.08574577]
#  [0.47729128 0.85943091 0.60380017 0.19346392]
#  [0.17951789 0.96160001 0.63037085 0.47411008]
#  [0.85165401 0.55900543 0.80071074 0.66912011]
#  [0.07085203 0.72707394 0.41921133 0.41325636]]
#           0         1         2         3
# 0  0.035200  0.268360  0.485876  0.085746
# 1  0.477291  0.859431  0.603800  0.193464
# 2  0.179518  0.961600  0.630371  0.474110
# 3  0.851654  0.559005  0.800711  0.669120
# 4  0.070852  0.727074  0.419211  0.413256
# Shape: (20, 4)
# First 5 rows:
# [[0.03519988 0.26836016 0.4858765  0.08574577]
#  [0.47729128 0.85943091 0.60380017 0.19346392]
#  [0.17951789 0.96160001 0.63037085 0.47411008]
#  [0.85165401 0.55900543 0.80071074 0.66912011]
#  [0.07085203 0.72707394 0.41921133 0.41325636]]

# %%
# print(xtest.head())
print(xtrain[:5])
# Out:
# [[-1.25182549 -0.62552444 -0.17562025 -1.30770844]
#  [ 0.11800424  1.3536855   0.34376286 -0.93852958]
#  [-0.80465302  1.69580036  0.46079079  0.02331973]
#  [ 1.27797522  0.34770592  1.21103598  0.69167115]
#  [-1.14135656  0.91048606 -0.46924039 -0.18524224]]

# %%
# print(ytrain.head())
print(ytrain[:5])
# Out:
# [1 0 1 1 1]

# %%
# print(ytest.head())
print(ytest[:5])
# Out:
# [1 0 1 1 1]

# %%
#standardising the data using standarscaler library 
from sklearn.preprocessing import StandardScaler 
sc = StandardScaler()

# %%
xtrain=sc.fit_transform(xtrain)
xtest=sc.fit_transform(xtest)

# %%
xtest
# Out:
# array([[ 0.19435781, -0.53420112, -1.44812108,  0.56358792],
#        [-1.21977995,  0.67206629, -0.64179048, -1.2866796 ],
#        [ 0.98100936, -1.20903577,  1.32055373, -1.59312085],
#        [ 1.5639381 ,  0.41893915, -1.62156325,  1.24473592],
#        [ 0.73166284, -0.0507417 ,  1.18536426, -1.21880004],
#        [-0.42234096,  1.2773749 , -0.76905162, -1.68081367],
#        [-1.01594931, -0.64634066, -0.38934902,  0.99218775],
#        [ 0.07870191, -1.38907736,  0.41474441, -1.7333373 ],
#        [-1.06891129, -0.8529781 ,  1.36422323, -0.54906875],
#        [-1.33212781, -1.50429904,  0.42342797, -0.83599053],
#        [ 0.96261507, -1.52519581,  0.21195143,  1.46865504],
#        [ 1.19491931, -1.16999342, -0.73947499, -1.09892605],
#        [-0.77911435,  1.53161846, -0.24282892,  1.56096431],
#        [ 1.54678562, -0.32331094,  0.65307319, -1.56815633],
#        [ 0.46165258, -1.71991116, -0.25116375, -0.16892991],
# ...

# %%
#linear Regression  aim is to find the best fit line

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
# machine learning done

# %%
# now its testing time
pred = lr.predict(xtest)
pred
# Out:
# array([0.59376446, 0.51712522, 0.46353075, 0.42447977, 0.44514053,
#        0.32356235, 0.86091053, 0.517956  , 0.81010911, 0.80151838,
#        0.77134127, 0.36977779, 0.74806362, 0.29403371, 0.63354397,
#        0.49427671, 0.9309434 , 0.31899762, 0.4129573 , 0.39889798,
#        0.54961061, 0.66570155, 0.77372342, 0.62217166, 0.56832837,
#        0.73224577, 0.63055649, 0.46030936, 0.47527756, 0.67063158,
#        0.48132742, 0.69313053, 0.71003821, 0.60510744, 0.84344139,
#        0.708586  , 0.78930425, 0.61868261, 0.31385298, 0.91153279,
#        0.74323494, 0.61956124, 0.30971774, 0.24168934, 0.41980423,
#        0.80351016, 0.84493681, 0.25236741, 0.45266727, 0.51390767,
#        0.30430017, 0.62102692, 0.48501571, 0.67126317, 0.87323486,
#        0.62360504, 0.3744694 , 0.84911272, 0.75766072, 0.27493438,
#        0.84658225, 0.96742217, 0.65850625, 0.96929115, 0.58080604,
#        0.32434651, 0.39400746, 0.69046272, 0.55237828, 0.55357157,
# ...

# %%
# to find the accuracy of the model we need to find the 
#MSE =  mean square error 
#and 
# r2score

# %%
from sklearn.metrics  import mean_squared_error
error = mean_squared_error(pred,ytest) #orginal value and tested value
error
# Out:
# 0.27777674305622996

# %%
# r2Score:-it is used to find the accuracy of the model 
from sklearn.metrics import r2_score
acc = r2_score(pred,ytest)
acc
# Out:
# -6.802341890082819

# %%
# to plot the best plot line we need to plot the lm plot
# lm plot stands for linear model plot

# %%
df = pd.DataFrame({'Y_Test':list(ytest),'Prediction':list(pred)})

# %%
df
# Out:
#     Y_Test  Prediction
# 0        1    0.593764
# 1        0    0.517125
# 2        1    0.463531
# 3        1    0.424480
# 4        1    0.445141
# ..     ...         ...
# 75       1    0.803914
# 76       0    0.708762
# 77       0    0.544721
# 78       1    0.504931
# 79       1    0.782426
#
# [80 rows x 2 columns]

# %%
sns.lmplot(x = 'Y_Test',y = 'Prediction',data = df)
plt.show()

# %%
# WE CAN RE RUN AND CHECK ACCURACY AND EVEN CHANGE THE TEST AND TRAIN SIZE
