# %% [markdown]
# # Machine Learning

# %% [markdown]
# ### Types of machine learning. Basically 3types but its 4 types
# #### 1. Supervised ML
# #### 2. Unsupervised ML
# #### 3. Reinforcrment ML
# #### 4. SemiSupervised ML

# %% [markdown]
# #### 1. Supervised ML:- Machine learns under supervision. in supervised ml we provied Labeled data.
# ###### give input and output

# %% [markdown]
# #### 2. UnSupervised ML:- in UnSupervised Machine learning is not under  supervision.We provied the UnLabeled data To the Machine .
# ##### here, the machine Tries to findout the result by finding name,pattern and features.

# %% [markdown]
# #### 3. Reinforcement ML :- In Reinforcement ML machine Learn from interacting with the Environment or hi and trial basis.Ex:-Game,Self driven Car, Robot etc.

# %% [markdown]
# #### 4. SemiSupervised ML:- Its also known as Hybrid Machine learning.
# ##### Bcz Its a Combination of Supervised and Unsuoervised Here, we provied machine Some labeled Data and Some Unlabeled Datas to the Machine

# %% [markdown]
# ### Supervised ML :- 2 types
# #### 1. Reggration Supervised ML
# #### 2. Classification Supervised ML

# %% [markdown]
# <h3> ================================================== </h3>

# %% [markdown]
# #### 1. Reggration Supervised ML :- It can be applied in the dataset in the where the output or the targeted datset is continous (Numrical Columns)
#
# <pre> Alogorithms:-      1. Linear Reggration
#                     2. Lasso Reggration
#                     3. Ridge Reggration
#                     4. Polynomical Regration
# </pre>

# %% [markdown]
# #### 2.Classification Model:- The Output will be in categrialcal columns
# <pre> Alogorithms:-      1. Logistict Reggration
#                     2. SVM(Support vector Machine) Reggration
#                     3. KNN(K Nearest Neigbour) Reggration
#                     4. Nabvie bayes Regration
# </pre>

# %% [markdown]
# #### Some steps of machine learning (Machine Learning Procedure):-
# * 1. DataSet Reading and Reading
# * 2. Data Clean and Analysis
# * 3. Data Visualization or (EDA-Exporitary Data Analysis)
# * 4. Encoding (its a process of converting string columns to integer columns)
# * 5. ip/op Creation (separating input data and output data)
# * 6. Train Test Spilt (separate the training data and testing data)
# * 7. Standard Scaler Transform (Standardizing all input datas( -3 to +3))
# * 8. machine Learning alorithim
# * 9. Prediction
# * 10. Result(Accuracy)

# %% [markdown]
# ### 1.Reggration Model :-

# %% [markdown]
# #### Linear Regression :-

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Reading the datasets:-
adv = pd.read_csv(r"C:\Users\suman\OneDrive\Documents\Desktop\AIML-CTTC-ALL-NOTES\Advertising-for ml(Linear Regressin)\advertising.csv")
adv
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
# data cleaning :-
# checking null value:-
adv.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
adv.dtypes
# Out:
# TV           float64
# Radio        float64
# Newspaper    float64
# Sales        float64
# dtype: object

# %%
# checking unique values:-
for i in adv.columns:
    print(f"{i}:\n {adv[i].unique()}\n")
# Out:
# TV:
#  [230.1  44.5  17.2 151.5 180.8   8.7  57.5 120.2   8.6 199.8  66.1 214.7
#   23.8  97.5 204.1 195.4  67.8 281.4  69.2 147.3 218.4 237.4  13.2 228.3
#   62.3 262.9 142.9 240.1 248.8  70.6 292.9 112.9  97.2 265.6  95.7 290.7
#  266.9  74.7  43.1 228.  202.5 177.  293.6 206.9  25.1 175.1  89.7 239.9
#  227.2  66.9 100.4 216.4 182.6 262.7 198.9   7.3 136.2 210.8 210.7  53.5
#  261.3 239.3 102.7 131.1  69.   31.5 139.3 216.8 199.1 109.8  26.8 129.4
#  213.4  16.9  27.5 120.5   5.4 116.   76.4 239.8  75.3  68.4 213.5 193.2
#   76.3 110.7  88.3 134.3  28.6 217.7 250.9 107.4 163.3 197.6 184.9 289.7
#  135.2 222.4 296.4 280.2 187.9 238.2 137.9  25.   90.4  13.1 255.4 225.8
#  241.7 175.7 209.6  78.2  75.1 139.2 125.7  19.4 141.3  18.8 224.  123.1
#  229.5  87.2   7.8  80.2 220.3  59.6   0.7 265.2   8.4 219.8  36.9  48.3
#   25.6 273.7  43.   73.4 193.7 220.5 104.6  96.2 140.3 243.2  38.   44.7
#  280.7 121.  171.3 187.8   4.1  93.9 149.8  11.7 131.7 172.5  85.7 188.4
# ...

# %%
adv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
# To check the statistical value of all columns
adv.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
# Data visualization:-

# %%
sns.scatterplot(x=adv.TV,y=adv.Sales , color="red")
plt.show()

# %%
sns.scatterplot(x=adv.Radio,y=adv.Sales,color="green")
plt.show()

# %%
sns.scatterplot(x=adv.Newspaper,y=adv.Sales, color="black")
plt.show()

# %%
sns.distplot(adv)
# Out:
# <Axes: ylabel='Density'>

# %%
import warnings 
warnings.filterwarnings("ignore")

# %%
sns.pairplot(adv,palette = 'hot')
plt.show()

# %%
#ploting heatmap
c = adv.corr()
c
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.901208
# Radio      0.054809  1.000000   0.354104  0.349631
# Newspaper  0.056648  0.354104   1.000000  0.157960
# Sales      0.901208  0.349631   0.157960  1.000000

# %%
sns.heatmap(c,annot=True,cmap='Reds')
plt.show()

# %%
# Encoding :-

# %%
# Creation of ip/op :-
adv
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
# ip will store all the input columns except the target one.
ip = adv.drop("Sales",axis=1)
ip.head()
# Out:
#       TV  Radio  Newspaper
# 0  230.1   37.8       69.2
# 1   44.5   39.3       45.1
# 2   17.2   45.9       69.3
# 3  151.5   41.3       58.5
# 4  180.8   10.8       58.4

# %%
op = adv.Sales
op.head()
# Out:
# 0    22.1
# 1    10.4
# 2    12.0
# 3    16.5
# 4    17.9
# Name: Sales, dtype: float64

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Train test split :- Splitting of the 100% datas to train and testing datas.
# from sklearn.model_selection import train_test_split
# xtrain,xtest,ytrain,ytest = train_test_split(ip,op,train_size=0.8)import numpy as np
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(ip, op, train_size=0.8)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[80], line 8
#       6 import matplotlib.pyplot as plt
#       7 import seaborn as sns
# ----> 8 from sklearn import train_test_split
#       9 xtrain, xtest, ytrain, ytest = train_test_split(ip, op, train_size=0.8)
#
# ImportError: cannot import name 'train_test_split' from 'sklearn' (C:\AnnacoondaAIML\Lib\site-packages\sklearn\__init__.py)

# %%
xtrain.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 xtrain.head()
#
# NameError: name 'xtrain' is not defined

# %%
ytrain.head()
