# %%
<h4>MACHINE LEARNING:-Machine Learns without being explicitly programmed.</h4>

# %%
#SEMI SUPERVISED ML:- IT IS A HYBRID MODEL BECAUSE IT A COMBINATION OF SUPERVISED AND UNSUPERVISED ML.
#HERE WE PROVIDE THE MACHINE SOME LABELLED DATAS AND SOME UNLABBEL DATAS

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
avt = pd.read_csv(r"E:\Downloads\archive\advertising.csv")
avt
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
avt.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
des = avt.describe(include = 'all')
des
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
avt.dtypes
# Out:
# TV           float64
# Radio        float64
# Newspaper    float64
# Sales        float64
# dtype: object

# %%
for i in avt.columns:
    print(i,":",avt[i].unique())
# Out:
# TV : [230.1  44.5  17.2 151.5 180.8   8.7  57.5 120.2   8.6 199.8  66.1 214.7
#   23.8  97.5 204.1 195.4  67.8 281.4  69.2 147.3 218.4 237.4  13.2 228.3
#   62.3 262.9 142.9 240.1 248.8  70.6 292.9 112.9  97.2 265.6  95.7 290.7
#  266.9  74.7  43.1 228.  202.5 177.  293.6 206.9  25.1 175.1  89.7 239.9
#  227.2  66.9 100.4 216.4 182.6 262.7 198.9   7.3 136.2 210.8 210.7  53.5
#  261.3 239.3 102.7 131.1  69.   31.5 139.3 216.8 199.1 109.8  26.8 129.4
#  213.4  16.9  27.5 120.5   5.4 116.   76.4 239.8  75.3  68.4 213.5 193.2
#   76.3 110.7  88.3 134.3  28.6 217.7 250.9 107.4 163.3 197.6 184.9 289.7
#  135.2 222.4 296.4 280.2 187.9 238.2 137.9  25.   90.4  13.1 255.4 225.8
#  241.7 175.7 209.6  78.2  75.1 139.2 125.7  19.4 141.3  18.8 224.  123.1
#  229.5  87.2   7.8  80.2 220.3  59.6   0.7 265.2   8.4 219.8  36.9  48.3
#   25.6 273.7  43.   73.4 193.7 220.5 104.6  96.2 140.3 243.2  38.   44.7
#  280.7 121.  171.3 187.8   4.1  93.9 149.8  11.7 131.7 172.5  85.7 188.4
#  163.5 117.2 234.5  17.9 206.8 215.4 284.3  50.  164.5  19.6 168.4 276.9
#  248.4 170.2 276.7 165.6 156.6 218.5  56.2 287.6 253.8 205.  139.5 191.1
#  10.6 23.2 19.8 16.4 10.7 22.6 21.2 20.2 23.7  5.5 23.8 18.4  8.1 24.2
#  14.  16.  11.  13.4 22.3 18.3 12.4  8.8  8.7  6.9 14.2  5.3 17.3 13.6
#  21.7 12.9 16.7  7.3 19.4 22.2 11.5 16.9 17.2 19.7 21.8 12.2  9.4 15.9
#   6.6 15.5  7.  15.2 24.7  1.6 17.7  5.7 19.6 10.8 11.6  9.5 20.8  9.6
#  10.9 19.2 20.1 12.3 10.3 18.2 20.6  3.2 15.3 13.3 19.9  8.  20.   8.4
#   7.6 27.  16.8 17.6 26.2  6.7  5.9 14.8 25.5]

# %%
avt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %% [markdown]
# <H1>DATA VISUALISATION</H1>

# %%
sns.scatterplot(x = avt.TV,y =avt.Sales,palette = "hot",hue = avt.Sales)
plt.show()

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
sns.scatterplot(x = avt.Radio,y =avt.Sales,palette = "hot",hue = avt.Sales)
plt.show()

# %%
sns.scatterplot(x = avt.Newspaper,y =avt.Sales,palette = "hot",hue = avt.Sales)
plt.show()

# %%
sns.lineplot(x = avt.Newspaper,y =avt.Sales,palette = "hot",hue = avt.Sales)
plt.show()

# %%
sns.lineplot(x = avt.Radio,y =avt.Sales,palette = "hot",hue = avt.Sales)
plt.show()

# %%
sns.lineplot(x = avt.Newspaper,y =avt.Sales,palette = "hot",hue = avt.Sales)
plt.show()

# %%
sns.jointplot(x = avt.Newspaper,y =avt.Sales,palette = "hot",hue = avt.Sales)
plt.show()

# %%
c = avt.corr()
c
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.901208
# Radio      0.054809  1.000000   0.354104  0.349631
# Newspaper  0.056648  0.354104   1.000000  0.157960
# Sales      0.901208  0.349631   0.157960  1.000000

# %%
sns.heatmap(c,annot = True,cmap = "Greens")
plt.show()

# %% [markdown]
# <h1>ENCONDING :- CONVERTING STRING TO INTEGER WE DONT NEED HERE AS NO S</h1>

# %%
#ENCODING

# %%
#CREATION OF IP/OP:-
# we take a variable ip that will store all input values except the target one for here tv radio and newspaper
ip = avt.drop('Sales',axis = 1)
ip.head()
# Out:
#       TV  Radio  Newspaper
# 0  230.1   37.8       69.2
# 1   44.5   39.3       45.1
# 2   17.2   45.9       69.3
# 3  151.5   41.3       58.5
# 4  180.8   10.8       58.4

# %%
op = avt.Sales
op.head()
# Out:
# 0    22.1
# 1    10.4
# 2    12.0
# 3    16.5
# 4    17.9
# Name: Sales, dtype: float64

# %% [markdown]
# <H1> DAY 14 STARTS</H1>

# %%
#Train Test Split:-
#splitting 100% of the data to training data to training and testing data.
# We need to give 80 percent data to machine
from sklearn.model_selection import train_test_split

# %%
#Input Training data = xtrain
#Output Training data  = ytrain
#Input Testing data  = xtest
#Output Testing data  = ytest
#train_size = 0.8
#or
#test_size = 0.2
xtrain,xtest,ytrain,ytest = train_test_split(ip,op,test_size = 0.8 '''random_state = 5''') 
#it executes untill  5 times 5th one will be final

# %%
print(xtrain.head())
# Out:
#         TV  Radio  Newspaper
# 24    62.3   12.6       18.3
# 6     57.5   32.8       23.5
# 125   87.2   11.8       25.9
# 26   142.9   29.3       12.6
# 3    151.5   41.3       58.5

# %%
print(xtest.head())
# Out:
#         TV  Radio  Newspaper
# 15   195.4   47.7       52.9
# 119   19.4   16.0       22.3
# 175  276.9   48.9       41.8
# 137  273.7   28.9       59.7
# 105  137.9   46.4       59.0

# %%
print(ytrain.head())
# Out:
# 24      9.7
# 6      11.8
# 125    10.6
# 26     15.0
# 3      16.5
# Name: Sales, dtype: float64

# %%
print(ytest.head())
# Out:
# 15     22.4
# 119     6.6
# 175    27.0
# 137    20.8
# 105    15.0
# Name: Sales, dtype: float64

# %%
#standardising the data using standarscaler library 
from sklearn.preprocessing import StandardScaler 
sc = StandardScaler()

# %%
xtrain=sc.fit_transform(xtrain)
xtest=sc.fit_transform(xtest)

# %%
xtest
# Out:
# array([[ 5.40257427e-01,  1.71279904e+00,  1.02189956e+00],
#        [-1.54526110e+00, -4.05697005e-01, -4.51065451e-01],
#        [ 1.50599470e+00,  1.79299447e+00,  4.87588725e-01],
#        [ 1.46807618e+00,  4.56403909e-01,  1.34922512e+00],
#        [-1.41090957e-01,  1.62592065e+00,  1.31552984e+00],
#        [ 5.14188445e-01, -2.45306137e-01,  1.63804179e+00],
#        [-1.44927985e+00, -1.36804221e+00, -5.28083229e-01],
#        [-9.82408092e-01, -6.93063976e-01,  2.46908167e-01],
#        [ 1.50362479e+00, -1.32126154e+00, -3.83674894e-01],
#        [-1.33789421e+00,  1.10465033e+00,  1.63322818e+00],
#        [ 4.15837287e-01,  1.45884683e+00, -1.44266935e+00],
#        [-2.97053083e-02,  1.22256268e-01, -6.05101008e-01],
#        [ 1.06993174e+00, -9.87113901e-01, -1.10571657e+00],
#        [-4.63398367e-01,  1.23830939e+00,  1.51770151e+00],
#        [ 3.88583352e-01,  1.61255475e+00,  1.30108901e+00],
#        [-1.73084707e-01,  1.31182187e+00,  6.84946783e-01],
#        [-8.82871980e-01, -1.18330033e-01,  3.99228875e-02],
#        [-1.12652068e-01, -1.34799335e+00, -1.09127573e+00],
#        [ 5.66326408e-01, -1.24106611e+00, -1.24049768e+00],
#        [ 1.25122965e+00,  3.22744853e-01, -1.25975213e+00],
#        [ 1.66951831e+00, -1.20096839e+00, -1.11534379e+00],
#        [-3.86376375e-01, -4.92575392e-01, -1.26456574e+00],
#        [ 3.67254185e-01, -7.53210552e-01,  1.28664818e+00],
#        [ 1.06637687e+00, -1.20096839e+00,  2.51721779e-01],
#        [ 1.04741762e+00,  8.17283362e-01, -1.26937935e+00],
#        [-1.06890971e+00, -6.73015118e-01,  5.50165670e-01],
#        [-1.18266527e+00, -6.99746929e-01, -6.38796286e-01],
#        [ 9.75135439e-01, -9.00235514e-01, -1.10571657e+00],
#        [ 1.33773127e+00,  4.49720957e-01, -7.59136565e-01],
#        [-5.85448599e-01, -8.33405986e-01, -1.35121074e+00],
#        [-1.24546782e+00,  2.49232372e-01, -5.32896840e-01],
#        [-1.30708541e+00,  1.27172415e+00, -1.24531129e+00],
#        [ 7.68953493e-01,  1.28939221e-01, -1.33195629e+00],
#        [-3.50827764e-01, -1.65110703e-01, -9.66121845e-01],
#        [-1.26442708e+00,  3.09378947e-01,  1.65076778e-01],
#        [ 2.54683582e-01,  1.17816281e+00,  2.90230668e-01],
#        [ 9.00483355e-01, -9.26967325e-01,  1.19518957e+00],
#        [-4.37329385e-01, -3.12135665e-01,  3.33553168e-01],
#        [ 3.06821546e-01, -4.45794722e-01, -1.40897407e+00],
#        [-8.69837490e-01, -1.42150583e+00, -8.12086288e-01],
#        [ 1.06993174e+00, -3.58916335e-01, -4.22183784e-01],
#        [-1.68864050e+00,  4.02940287e-01,  4.68334281e-01],
#        [ 1.65766878e+00,  1.35191959e+00,  9.40068174e-01],
#        [-3.47272903e-01,  4.29672098e-01, -8.40967954e-01],
#        [ 3.22225944e-01, -8.53454844e-01, -1.21642962e+00],
#        [ 9.30107198e-01, -3.45550429e-01, -2.63334615e-01],
#        [-6.62470590e-01,  1.43211502e+00,  9.06372896e-01],
#        [-1.00802531e-01,  3.16061900e-01,  6.99387616e-01],
#        [ 9.44326642e-01,  6.83624305e-01,  2.04719874e+00],
#        [ 5.92395390e-01, -1.26779792e+00,  1.41008722e-01],
#        [ 4.50200945e-01, -6.48664108e-02, -1.06720768e+00],
#        [-1.67205115e+00,  1.79299447e+00,  2.08570763e+00],
#        [ 7.21555344e-01,  4.96501626e-01, -1.07683490e+00],
#        [-1.72655902e+00, -6.99746929e-01, -1.25012490e+00],
#        [-1.55237083e+00, -2.47686939e-02,  9.01559285e-01],
#        [-6.23367118e-01, -1.37472516e+00, -8.04173914e-02],
#        [ 1.55102294e+00, -5.46039014e-01,  2.56535390e-01],
#        [-2.14558087e-01, -2.45306137e-01,  1.41008722e-01],
#        [ 7.54734048e-01,  1.39870026e+00,  1.02499833e-01],
#        [ 1.59887285e-01,  6.36843636e-01,  1.02189956e+00],
#        [ 1.61382549e+00, -5.46039014e-01, -1.34639713e+00],
#        [ 5.84100714e-01,  5.70014107e-01,  3.38366779e-01],
#        [ 1.87141221e-01, -8.06674174e-01, -6.77305175e-01],
#        [ 1.55931762e+00,  1.17147986e+00,  1.16149429e+00],
#        [ 7.22740298e-01,  1.83977514e+00,  2.90230668e-01],
#        [-1.83749291e-01, -1.14750477e+00, -1.07683490e+00],
#        [-7.28827998e-01,  2.29183513e-01,  2.00868985e+00],
#        [ 1.58538660e+00,  1.33187073e+00,  1.66210985e+00]])

# %%
#linear Regression  aim is to find the best fit line

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
# machine learning done

# %%
# now its testing time
pred = lr.predict(xtest)
pred
# Out:
# array([19.44193735,  6.85061324, 24.32071357, 22.5282715 , 15.97092187,
#        17.00787415,  6.21674676,  9.23493136, 20.77611578,  9.46267232,
#        18.71609457, 14.92160936, 19.08248914, 13.92424146, 18.56030039,
#        15.49674452, 10.40294915, 12.85138307, 16.32341001, 21.49748153,
#        21.78367395, 12.50621047, 15.72459254, 18.71945289, 21.0673618 ,
#         8.81083019,  8.30713405, 18.71681539, 22.03296599, 11.14032895,
#         9.08656727, 12.43173811, 17.17159406, 13.30495145,  7.93491958,
#         8.173451  ,  7.02620922, 21.06762366,  5.22329928, 12.14617477,
#        11.83421007, 20.48509378, 22.88843929, 10.11271445, 21.74262885,
#        18.32527265, 16.32860344, 20.07956269, 12.75867441, 10.4007341 ,
#         9.84571751, 16.94329448, 19.23648283, 10.9763042 , 21.49418188,
#         6.23009382, 24.3837646 ,  5.26820905, 12.60995174, 10.03107524,
#        21.57732187, 11.85776089, 16.77368959, 20.24865423, 19.91692925,
#         9.29757624,  6.76507306, 16.01013514, 10.93900043, 23.65806015,
#        10.9965952 , 14.45650092,  8.8655735 , 12.56756221,  5.77159069,
#        14.87621049, 10.10614221,  9.77159003, 14.95675291, 11.4551003 ,
#        11.17354072,  6.38628538, 17.3162291 , 17.82240269,  9.76831017,
#         9.77412484,  8.28940427, 21.16647054, 19.75217763, 17.74239495,
#         7.84320797, 12.089962  , 15.59302864,  8.77707311, 18.83068465,
#        22.35667218, 17.96980995, 15.90133985, 16.84534452, 20.88644464,
#        17.73510982, 13.85732256,  7.8577779 , 13.92106819, 18.70368288,
#        20.47605718, 14.36113976,  7.19720348, 17.6762332 , 16.38955089,
#        19.62372666, 19.60366389,  6.50501911, 18.84296636, 17.61227685,
#        11.86210982, 11.95232793, 19.7946564 ,  7.63017063, 10.42796165,
#        20.08505924, 18.1892126 , 19.8374563 , 10.01616053, 18.90816141,
#        13.03742505,  9.0121196 , 17.47388918, 18.15182677, 12.3480092 ,
#        15.97833217,  9.0240527 , 19.75825656,  7.01279023, 24.52410202,
#        13.73264381, 15.56931733, 19.07480459, 13.21385504, 14.70114838,
#        20.16531564, 16.32033283, 17.09821042,  8.58203651, 19.08107833,
#         5.67787948,  7.15728721, 10.23651726, 21.85780887, 13.53426421,
#        20.20033556, 16.32964263, 22.28297539, 18.38746559, 14.92012695,
#        23.81617806, 20.53876243, 12.73235308, 11.4184747 , 24.09317504])

# %%
# to find the accuracy of the model we need to find the 
#MSE =  mean square error 
#and 
# r2score

# %%
from sklearn.metrics  import mean_squared_error
error = mean_squared_error(pred,ytest) #orginal value and tested value
error
# Out:
# 3.3303967658207414

# %%
# r2Score:-it is used to find the accuracy of the model 
from sklearn.metrics import r2_score
acc = r2_score(pred,ytest)
acc
# Out:
# 0.8732438267736103

# %%
# to plot the best plot line we need to plot the lm plot
# lm plot stands for linear model plot

# %%
df = pd.DataFrame({'Y_Test':list(ytest),'Prediction':list(pred)})

# %%
df
# Out:
#      Y_Test  Prediction
# 0      22.4   19.441937
# 1       6.6    6.850613
# 2      27.0   24.320714
# 3      20.8   22.528272
# 4      15.0   15.970922
# ..      ...         ...
# 155    24.4   23.816178
# 156    23.8   20.538762
# 157    14.0   12.732353
# 158    12.9   11.418475
# 159    25.5   24.093175
#
# [160 rows x 2 columns]

# %%
sns.lmplot(x = 'Y_Test',y = 'Prediction',data = df)
plt.show()

# %%
# WE CAN RE RUN AND CHECK ACCURACY AND EVEN CHANGE THE TEST AND TRAIN SIZE
