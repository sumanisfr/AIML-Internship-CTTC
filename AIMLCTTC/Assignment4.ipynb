# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mpg=pd.read_csv(r"C:\Users\suman\OneDrive\Documents\Desktop\AIML-CTTC-ALL-NOTES\auto-mpg.csv")
mpg
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
mpg.columns=['mpg','cylinders','displacement','horsepower','weight','acceleration','model year','origin','car_name']
mpg
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car_name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
mpg.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# model year        int64
# origin            int64
# car_name         object
# dtype: object

# %%
mpg.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car_name        0
# dtype: int64

# %%
for i in mpg.columns:
    print(f"{i}\n:{mpg[i].unique()}\n")
# Out:
# mpg
# :[18.  15.  16.  17.  14.  24.  22.  21.  27.  26.  25.  10.  11.   9.
#  28.  19.  12.  13.  23.  30.  31.  35.  20.  29.  32.  33.  17.5 15.5
#  14.5 22.5 24.5 18.5 29.5 26.5 16.5 31.5 36.  25.5 33.5 20.5 30.5 21.5
#  43.1 36.1 32.8 39.4 19.9 19.4 20.2 19.2 25.1 20.6 20.8 18.6 18.1 17.7
#  27.5 27.2 30.9 21.1 23.2 23.8 23.9 20.3 21.6 16.2 19.8 22.3 17.6 18.2
#  16.9 31.9 34.1 35.7 27.4 25.4 34.2 34.5 31.8 37.3 28.4 28.8 26.8 41.5
#  38.1 32.1 37.2 26.4 24.3 19.1 34.3 29.8 31.3 37.  32.2 46.6 27.9 40.8
#  44.3 43.4 36.4 44.6 40.9 33.8 32.7 23.7 23.6 32.4 26.6 25.8 23.5 39.1
#  39.  35.1 32.3 37.7 34.7 34.4 29.9 33.7 32.9 31.6 28.1 30.7 24.2 22.4
#  34.  38.  44. ]
#
# cylinders
# :[8 4 6 3 5]
#
# displacement
# :[307.  350.  318.  304.  302.  429.  454.  440.  455.  390.  383.  340.
#  400.  113.  198.  199.  200.   97.  110.  107.  104.  121.  360.  140.
#   98.  232.  225.  250.  351.  258.  122.  116.   79.   88.   71.   72.
# ...

# %%
for i in mpg.columns:
    print(f"{i}:{sum(mpg[i]=='?')}")
# Out:
# mpg:0
# cylinders:0
# displacement:0
# horsepower:6
# weight:0
# acceleration:0
# model year:0
# origin:0
# car_name:0

# %%
des=mpg.describe(include='all')
des
# Out:
#                mpg   cylinders  displacement horsepower       weight  \
# count   398.000000  398.000000    398.000000        398   398.000000
# unique         NaN         NaN           NaN         94          NaN
# top            NaN         NaN           NaN        150          NaN
# freq           NaN         NaN           NaN         22          NaN
# mean     23.514573    5.454774    193.425879        NaN  2970.424623
# std       7.815984    1.701004    104.269838        NaN   846.841774
# min       9.000000    3.000000     68.000000        NaN  1613.000000
# 25%      17.500000    4.000000    104.250000        NaN  2223.750000
# 50%      23.000000    4.000000    148.500000        NaN  2803.500000
# 75%      29.000000    8.000000    262.000000        NaN  3608.000000
# max      46.600000    8.000000    455.000000        NaN  5140.000000
#
#         acceleration  model year      origin    car_name
# count     398.000000  398.000000  398.000000         398
# ...

# %%
mpg['horsepower'].replace('?',des['horsepower'][2],inplace=True)
# Out:
# C:\Users\asish\AppData\Local\Temp\ipykernel_10800\1523576847.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   mpg['horsepower'].replace('?',des['horsepower'][2],inplace=True)
# C:\Users\asish\AppData\Local\Temp\ipykernel_10800\1523576847.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
# ...

# %%
for i in mpg.columns:
    print(f"{i}:\n{mpg[i].unique()}\n")
# Out:
# mpg:
# [18.  15.  16.  17.  14.  24.  22.  21.  27.  26.  25.  10.  11.   9.
#  28.  19.  12.  13.  23.  30.  31.  35.  20.  29.  32.  33.  17.5 15.5
#  14.5 22.5 24.5 18.5 29.5 26.5 16.5 31.5 36.  25.5 33.5 20.5 30.5 21.5
#  43.1 36.1 32.8 39.4 19.9 19.4 20.2 19.2 25.1 20.6 20.8 18.6 18.1 17.7
#  27.5 27.2 30.9 21.1 23.2 23.8 23.9 20.3 21.6 16.2 19.8 22.3 17.6 18.2
#  16.9 31.9 34.1 35.7 27.4 25.4 34.2 34.5 31.8 37.3 28.4 28.8 26.8 41.5
#  38.1 32.1 37.2 26.4 24.3 19.1 34.3 29.8 31.3 37.  32.2 46.6 27.9 40.8
#  44.3 43.4 36.4 44.6 40.9 33.8 32.7 23.7 23.6 32.4 26.6 25.8 23.5 39.1
#  39.  35.1 32.3 37.7 34.7 34.4 29.9 33.7 32.9 31.6 28.1 30.7 24.2 22.4
#  34.  38.  44. ]
#
# cylinders:
# [8 4 6 3 5]
#
# displacement:
# [307.  350.  318.  304.  302.  429.  454.  440.  455.  390.  383.  340.
#  400.  113.  198.  199.  200.   97.  110.  107.  104.  121.  360.  140.
#   98.  232.  225.  250.  351.  258.  122.  116.   79.   88.   71.   72.
# ...

# %%
mpg.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# model year        int64
# origin            int64
# car_name         object
# dtype: object

# %%
mpg.horsepower=mpg.horsepower.astype('float')

# %%
mpg.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model year        int64
# origin            int64
# car_name         object
# dtype: object

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car_name      398 non-null    object
# dtypes: float64(4), int64(4), object(1)
# memory usage: 28.1+ KB

# %%
sns.distplot(x=mpg.mpg)
plt.show()
# Out:
# C:\Users\asish\AppData\Local\Temp\ipykernel_10800\4005954114.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=mpg.mpg)

# %%
sns.kdeplot(x=mpg.mpg)
plt.show()

# %%
# plt.figure(figsize=(15,40))
sns.scatterplot(x=mpg.acceleration,y=mpg.mpg)
plt.show()

# %%
sns.histplot(x=mpg.mpg,y=mpg.horsepower,palette='cool')
plt.show()
# Out:
# C:\Users\asish\AppData\Local\Temp\ipykernel_10800\3667461584.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(x=mpg.mpg,y=mpg.horsepower,palette='cool')

# %%
sns.boxplot(x=mpg.mpg,y=mpg.origin,color='darkred')
plt.show()

# %%
sns.pairplot(mpg)
plt.show()

# %%
mpg.drop('car_name',axis=1,inplace=True)

# %%
c=mpg.corr()

# %%
sns.heatmap(c,annot=True)
# Out:
# <Axes: >

# %%
ip=mpg.drop('mpg',axis=1)

# %%
ip.head()
# Out:
#    cylinders  displacement  horsepower  weight  acceleration  model year  \
# 0          8         307.0       130.0    3504          12.0          70
# 1          8         350.0       165.0    3693          11.5          70
# 2          8         318.0       150.0    3436          11.0          70
# 3          8         304.0       150.0    3433          12.0          70
# 4          8         302.0       140.0    3449          10.5          70
#
#    origin
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
op=mpg.mpg
op.head()
# Out:
# 0    18.0
# 1    15.0
# 2    18.0
# 3    16.0
# 4    17.0
# Name: mpg, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(ip,op,test_size=0.15)
xtrain.head()
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model year  \
# 39           8         400.0       175.0    4464          11.5          71
# 73           8         307.0       130.0    4098          14.0          72
# 257          6         232.0        90.0    3210          17.2          78
# 44           8         400.0       175.0    5140          12.0          71
# 381          4         107.0        75.0    2205          14.5          82
#
#      origin
# 39        1
# 73        1
# 257       1
# 44        1
# 381       3

# %%
xtest.head()
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model year  \
# 4            8         302.0       140.0    3449          10.5          70
# 364          8         350.0       105.0    3725          19.0          81
# 366          6         225.0        85.0    3465          16.6          81
# 319          4         120.0        75.0    2542          17.5          80
# 296          4         121.0        80.0    2670          15.0          79
#
#      origin
# 4         1
# 364       1
# 366       1
# 319       3
# 296       1

# %%
ytest.head()
# Out:
# 4      17.0
# 364    26.6
# 366    17.6
# 319    31.3
# 296    27.4
# Name: mpg, dtype: float64

# %%
ytrain.head()
# Out:
# 39     14.0
# 73     13.0
# 257    19.4
# 44     13.0
# 381    36.0
# Name: mpg, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
xtrain=sc.fit_transform(xtrain)
xtrain
# Out:
# array([[ 1.48653076,  1.98836902,  1.82002547, ..., -1.50518718,
#         -1.37149016, -0.72213513],
#        [ 1.48653076,  1.09372036,  0.64772991, ..., -0.59643956,
#         -1.10087506, -0.72213513],
#        [ 0.31668816,  0.37222951, -0.39431059, ...,  0.56675739,
#          0.52281557, -0.72213513],
#        ...,
#        [ 1.48653076,  1.98836902,  1.16875016, ..., -1.32343766,
#         -0.83025995, -0.72213513],
#        [ 0.31668816,  0.06439341, -0.52456565, ...,  0.93025644,
#          0.79343068, -0.72213513],
#        [-0.85315444, -0.35888122, -0.0035454 , ...,  0.38500787,
#          0.52281557, -0.72213513]])

# %%
xtest=sc.fit_transform(xtest)
xtest
# Out:
# array([[ 1.56816631,  1.02580831,  0.87986674,  0.60017681, -1.70248578,
#         -1.55161979, -0.67663658],
#        [ 1.56816631,  1.48214564, -0.00675521,  0.93258243,  1.40401779,
#          1.45151529, -0.67663658],
#        [ 0.34621854,  0.29376716, -0.51339633,  0.6194467 ,  0.52688737,
#          1.45151529, -0.67663658],
#        [-0.87572924, -0.70447076, -0.76671689, -0.49218513,  0.85581128,
#          1.17850301,  1.9426018 ],
#        [-0.87572924, -0.69496374, -0.64005661, -0.338026  , -0.05786624,
#          0.90549073, -0.67663658],
#        [ 1.56816631,  1.04482236,  1.1331873 ,  0.86875091, -1.33701477,
#         -0.73258295, -0.67663658],
#        [ 0.34621854,  0.35080933, -0.00675521,  0.5170754 ,  0.23451056,
#          0.63247845, -0.67663658],
#        [-0.87572924, -0.91362538, -0.9947054 , -1.38582632, -0.27714885,
#          0.63247845, -0.67663658],
#        [ 1.56816631,  1.17792075,  1.1331873 ,  1.42637338, -0.60607276,
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
pred=lr.predict(xtest)
pred
# Out:
# array([15.38178109, 22.74208091, 23.75822212, 31.16640673, 26.95011592,
#        16.11862584, 21.986464  , 31.75445534, 12.52489281, 32.41944222,
#        23.81029153, 35.95595112, 28.76792712, 27.76376722, 25.30560127,
#        28.60492659, 29.54362338, 27.23038323, 31.21102956, 21.00561405,
#        33.69424574, 23.53900704, 24.95141342, 27.14789617, 16.47503197,
#        24.64394235, 18.73777285, 32.20775969, 19.9036894 , 31.28922675,
#        10.06535489, 27.79418576, 25.48754897, 24.15145816, 13.67890844,
#        34.31122198, 23.29298351, 19.30306527, 12.0268381 , 26.00006577,
#        23.52303224, 26.31974038, 10.71743852, 21.42216428, 20.97993835,
#        24.5509203 , 16.62633079, 18.0480976 , 10.21614341, 10.71122528,
#        34.11950912, 30.04747874, 17.41416488, 23.67967477, 27.06702073,
#        34.170084  , 20.53436785, 11.89790256, 26.83134335, 17.62138801])

# %%
from sklearn.metrics import mean_squared_error
error=mean_squared_error(pred,ytest)
error
# Out:
# 13.57007799996776

# %%
from sklearn.metrics import r2_score
rs=r2_score(pred,ytest)
rs
# Out:
# 0.7124467864826527

# %%
df1=pd.DataFrame({'Y_test':list(ytest),'prediction':list(pred)})
df
# Out:
#     Y_test  prediction
# 0     16.0   12.837416
# 1     16.9   17.779205
# 2     21.0   21.148981
# 3     17.0   23.401965
# 4     28.8   26.176610
# ..     ...         ...
# 95    38.0   31.790296
# 96    32.0   35.634349
# 97    32.3   34.797258
# 98    13.0   11.200041
# 99    12.0   11.504053
#
# [100 rows x 2 columns]

# %%
sns.lmplot(x='Y_test',y='prediction',data=df1)
plt.title("LM PLOT")
plt.show()

# %% [markdown]
# ## Classification Model-:
